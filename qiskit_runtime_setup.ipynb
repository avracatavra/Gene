# %% [markdown]
# # setup
# 설치때 단 한번 수행하면 된

# %%
# from qiskit_ibm_runtime import QiskitRuntimeService
# QiskitRuntimeService.save_account(
# token="",
# instance="",

# channel="ibm_quantum_platform", # 중요
# overwrite=True )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from qiskit_ibm_runtime import QiskitRuntimeService
#       2 QiskitRuntimeService.save_account(
#       3 token="e1hyIiFwhLxDXQXa71FXc7JM8Au2j2dpOd5bNtcquPKB",
#       4 instance="crn:v1:bluemix:public:quantum-computing:us-east:a/915b1ffaa8b046e29d52acddc9e955c4:5036094e-de11-4753-b3de-867fca59eb7d::",
#       5
#       6 channel="ibm_quantum_platform", # 중요
#       7 overwrite=True )
#
# ModuleNotFoundError: No module named 'qiskit_ibm_runtime'

# %% [markdown]
# # test

# %%
# 사용가능한 백엔드 서칭
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(  )
backends = service.backends()
print([b.name for b in backends])
# Out:
# ['ibm_brisbane', 'ibm_sherbrooke', 'ibm_torino']

# %%
from qiskit import QuantumCircuit
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2

service = QiskitRuntimeService()

# sim_backend = service.least_busy(filters=lambda b:b.configuration().simulator and b.status().operational)
# print(sim_backend.name)

#backend = service.least_busy(simulator=True)

#backend=[b for b in backends if b.name == 'ibm_brisbane'][0]

backend=service.backend('ibm_torino')
