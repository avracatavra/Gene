# %%
import qiskit

# %%
import sys
print(sys.path) # lists all the paths, "returns a list"
# Out:
# ['c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\python310.zip', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\DLLs', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\lib', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime', '', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\lib\\site-packages', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\lib\\site-packages\\win32', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\lib\\site-packages\\win32\\lib', 'c:\\Users\\Gene\\anaconda3\\envs\\qiskit_runtime\\lib\\site-packages\\Pythonwin']

# %% [markdown]
# # sample

# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit import transpile
from qiskit_aer import AerSimulator

# 회로 생성
qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)

# 시뮬레이터에서 실행
simulator = AerSimulator()
compiled_circuit = transpile(qc, simulator)
result = simulator.run(compiled_circuit, shots=1024).result()
counts = result.get_counts()
print(counts)
# Out:
# {'1': 499, '0': 525}
